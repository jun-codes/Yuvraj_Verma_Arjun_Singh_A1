# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\yuvra\\OneDrive\\Desktop\\Monsoon 2025\\iml_assignments\\Yuvraj_Verma_Arjun_Singh_A1\\laptop_price_task\\data\\train_data.csv")

# %%
data.head()
# Out:
#   Company            TypeName  Inches       ScreenResolution  \
# 0    Acer            Notebook    15.6      Full HD 1920x1080
# 1    Asus            Notebook    14.0               1366x768
# 2    Dell            Notebook    15.6               1366x768
# 3  Lenovo  2 in 1 Convertible    14.0  Touchscreen 2560x1440
# 4    Acer            Notebook    15.6               1366x768
#
#                                     Cpu   Ram              Memory  \
# 0           Intel Core i7 7700HQ 2.8GHz   8GB           256GB SSD
# 1  Intel Celeron Dual Core N3350 1.1GHz   4GB  32GB Flash Storage
# 2  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 3            Intel Core i7 7500U 2.7GHz  16GB             1TB SSD
# 4              Intel Core i3 6006U 2GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight       Price
# 0  Nvidia GeForce GTX 1050 Ti       Linux   2.5kg   52161.120
# 1       Intel HD Graphics 500  Windows 10   1.5kg   14811.840
# ...

# %%
data.tail()
# Out:
#      Company   TypeName  Inches   ScreenResolution  \
# 1167    Dell  Ultrabook    14.0  Full HD 1920x1080
# 1168    Dell     Gaming    15.6  Full HD 1920x1080
# 1169  Lenovo   Notebook    17.3           1600x900
# 1170  Lenovo     Gaming    15.6  Full HD 1920x1080
# 1171      HP  Ultrabook    12.5  Full HD 1920x1080
#
#                               Cpu   Ram     Memory  \
# 1167   Intel Core i7 7600U 2.8GHz   8GB  512GB SSD
# 1168  Intel Core i5 7300HQ 2.5GHz   8GB  256GB SSD
# 1169   Intel Core i5 7200U 2.5GHz   4GB    1TB HDD
# 1170  Intel Core i7 7700HQ 2.8GHz  16GB  512GB SSD
# 1171   Intel Core i5 6200U 2.3GHz   4GB  500GB HDD
#
#                              Gpu       OpSys  Weight     Price
# 1167           Intel HD Graphics  Windows 10  1.36kg  89510.40
# 1168     Nvidia GeForce GTX 1050  Windows 10  2.56kg  46833.12
# 1169        Nvidia GeForce 920MX  Windows 10  2.79kg  31381.92
# 1170  Nvidia GeForce GTX 1050 Ti  Windows 10   2.4kg  63882.72
# ...

# %%
# Sanity check
data.shape
# Out:
# (1172, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1172 non-null   object
#  1   TypeName          1172 non-null   object
#  2   Inches            1172 non-null   float64
#  3   ScreenResolution  1172 non-null   object
#  4   Cpu               1172 non-null   object
#  5   Ram               1172 non-null   object
#  6   Memory            1172 non-null   object
#  7   Gpu               1172 non-null   object
#  8   OpSys             1172 non-null   object
#  9   Weight            1172 non-null   object
#  10  Price             1172 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 100.8+ KB

# %%
# missing values
data.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# check duplicates
data.duplicated().sum()

#25 duplicates - Remove duplicates in pre-processing
# Out:
# 25

# %%
# garbage values (No garbage values)

for i in data.select_dtypes(include = "object").columns:
    print(data[i].value_counts())
    print("*****" * 10)
# Out:
# Company
# Lenovo       268
# Dell         262
# HP           253
# Asus         138
# Acer          95
# MSI           49
# Toshiba       43
# Apple         20
# Razer          7
# Samsung        7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Fujitsu        3
# Vero           3
# Huawei         2
# LG             2
# Chuwi          2
# Google         1
# Name: count, dtype: int64
# **************************************************
# TypeName
# Notebook              660
# Gaming                187
# Ultrabook             172
# 2 in 1 Convertible    103
# Workstation            27
# Netbook                23
# Name: count, dtype: int64
# **************************************************
# ScreenResolution
# Full HD 1920x1080                                460
# 1366x768                                         251
# IPS Panel Full HD 1920x1080                      216
# IPS Panel Full HD / Touchscreen 1920x1080         46
# ...

# %%
data.describe() #to see the stats for the float data
# Out:
#            Inches          Price
# count  1172.00000    1172.000000
# mean     15.04343   60081.426123
# std       1.41257   37460.969532
# min      10.10000    9270.720000
# 25%      14.00000   32114.520000
# 50%      15.60000   52161.120000
# 75%      15.60000   79346.840400
# max      17.30000  324954.720000

# %%
#histogram
plt.xticks(rotation='vertical')
for i in data.select_dtypes(include = "number").columns:
    sns.histplot(data=data, x = i)
    plt.show()

# %%
for i in data.select_dtypes(include = "object").columns:
    plt.xticks(rotation='vertical')
    sns.histplot(data=data, x = i)
    plt.show()

# %%
for i in data.select_dtypes(include = "number").columns:
    sns.boxplot(data=data, x = i)
    plt.show()

# %%
for i in data.select_dtypes(include = "object").columns:
    sns.boxplot(data=data, x = i)
    plt.show()

# %%
data.select_dtypes(include = "number").columns

for i in ['Inches']:
    sns.scatterplot(data= data, x = i, y = 'Price')
    plt.show()

# %%
data.select_dtypes(include = "object").columns

for i in ['Company', 'TypeName', 'ScreenResolution', 'Cpu', 'Ram', 'Memory',
       'Gpu', 'OpSys', 'Weight']:
    sns.scatterplot(data= data, x = i, y = 'Price')
    plt.show()

# %%
data.select_dtypes(include = "number").corr()
# Out:
#          Inches    Price
# Inches  1.00000  0.07221
# Price   0.07221  1.00000

# %%
map=data.select_dtypes(include = "number").corr()
plt.figure(figsize= (15,15))
sns.heatmap(map, annot = True)
# Out:
# <Axes: >

# %%
data['Ram'] = data['Ram'].str.replace('GB','')
data['Weight'] = data['Weight'].str.replace('kg','')

# %%
data['Ram'] = data['Ram'].str.strip().astype(int)      
data['Weight'] = data['Weight'].str.strip().astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1172 non-null   object
#  1   TypeName          1172 non-null   object
#  2   Inches            1172 non-null   float64
#  3   ScreenResolution  1172 non-null   object
#  4   Cpu               1172 non-null   object
#  5   Ram               1172 non-null   int32
#  6   Memory            1172 non-null   object
#  7   Gpu               1172 non-null   object
#  8   OpSys             1172 non-null   object
#  9   Weight            1172 non-null   float64
#  10  Price             1172 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 96.3+ KB

# %%
sns.distplot(data["Price"])
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_24500\4278785232.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.barplot(x = data["Company"], y = data["Price"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.barplot(x = data["TypeName"], y = data["Price"])
plt.xticks(rotation = "vertical")
plt.show()

# %%
sns.distplot(data["Inches"])
# Out:
# C:\Users\yuvra\AppData\Local\Temp\ipykernel_24500\1393952615.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Inches"])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
#Now we will use the processed data to find out more correlations

# %%
new_data = pd.read_csv("C:\\Users\\yuvra\\OneDrive\\Desktop\\Monsoon 2025\\iml_assignments\\Yuvraj_Verma_Arjun_Singh_A1\\laptop_price_task\\data\\train_data__processed.csv")

# %%
sns.barplot(x=new_data['Touchscreen'], y= new_data['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
sns.barplot(x=new_data['Ips'], y= new_data['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1146 entries, 0 to 1145
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Company                          1146 non-null   object
#  1   TypeName                         1146 non-null   object
#  2   Inches                           1146 non-null   float64
#  3   ScreenResolution                 1146 non-null   object
#  4   Cpu                              1146 non-null   object
#  5   Ram                              1146 non-null   int64
#  6   Memory                           1146 non-null   object
#  7   Gpu                              1146 non-null   object
#  8   OpSys                            1146 non-null   object
#  9   Weight                           1146 non-null   float64
#  10  Price                            1146 non-null   float64
#  11  Touchscreen                      1146 non-null   int64
# ...

# %%
new_data.corr(numeric_only=True)['Price']
# Out:
# Inches                             0.067798
# Ram                                0.739347
# Weight                             0.216327
# Price                              1.000000
# Touchscreen                        0.195435
# Ips                                0.260489
# X_res                              0.551117
# Y_res                              0.548961
# ppi                                0.469245
# HDD                               -0.099023
# SSD                                0.659172
# Hybrid                             0.034488
# Flash_Storage                     -0.026140
# gpu_AMD                           -0.206831
# gpu_Intel                         -0.179005
# gpu_Nvidia                         0.344211
# cpu_brand_AMD Processor           -0.185866
# cpu_brand_Intel Core i3           -0.289797
# cpu_brand_Intel Core i5           -0.125762
# cpu_brand_Intel Core i7            0.557636
# cpu_brand_Other Intel Processor   -0.277496
# Name: Price, dtype: float64

# %%
plt.figure(figsize= (15,15))
sns.heatmap(new_data.corr(numeric_only=True), annot= True)
# Out:
# <Axes: >
