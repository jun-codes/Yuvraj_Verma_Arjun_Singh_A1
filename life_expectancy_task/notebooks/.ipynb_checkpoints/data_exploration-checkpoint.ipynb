# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\Users\\yuvra\\OneDrive\\Desktop\\Monsoon 2025\\iml_assignments\\Yuvraj_Verma_Arjun_Singh_A1\\life_expectancy_task\\data\\train_data.csv")

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0      Hungary  2009   Developed              74.2            162.0
# 1    Singapore  2010   Developed              82.0             61.0
# 2  New Zealand  2008   Developed              81.0             75.0
# 3     Honduras  2000  Developing              71.0            174.0
# 4        Egypt  2002  Developing              68.7            177.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0              0    11.46             1281.155944          NaN         1  ...
# 1              0     1.84             4540.543752         96.0        50  ...
# 2              0     9.49             6761.288966          9.0         0  ...
# 3              6     2.61               28.808311         93.0         0  ...
# 4             61     0.15                0.000000         97.0       653  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS           GDP  Population  \
# ...

# %%
data.tail()
# Out:
#                      Country  Year      Status  Life expectancy   \
# 2492                 Belgium  2012   Developed              83.0
# 2493  Bosnia and Herzegovina  2014  Developing              77.2
# 2494           Guinea-Bissau  2001  Developing              52.5
# 2495                  France  2014  Developing              82.2
# 2496        Papua New Guinea  2006  Developing              68.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 2492             78.0              0    10.08              664.473898
# 2493             89.0              0     4.03              732.866249
# 2494             32.0              5     2.55                0.868708
# 2495             79.0              3    11.50             6739.677606
# 2496            299.0             11     0.64              126.614214
#
#       Hepatitis B  Measles   ...  Polio  Total expenditure  Diphtheria   \
# 2492         98.0       109  ...   99.0               1.54         99.0
# ...

# %%
# Sanity check
data.shape
# Out:
# (2497, 22)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2497 entries, 0 to 2496
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2497 non-null   object
#  1   Year                             2497 non-null   int64
#  2   Status                           2497 non-null   object
#  3   Life expectancy                  2488 non-null   float64
#  4   Adult Mortality                  2488 non-null   float64
#  5   infant deaths                    2497 non-null   int64
#  6   Alcohol                          2333 non-null   float64
#  7   percentage expenditure           2497 non-null   float64
#  8   Hepatitis B                      2016 non-null   float64
#  9   Measles                          2497 non-null   int64
#  10   BMI                             2466 non-null   float64
#  11  under-five deaths                2497 non-null   int64
# ...

# %%
# missing values
data.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                      9
# Adult Mortality                      9
# infant deaths                        0
# Alcohol                            164
# percentage expenditure               0
# Hepatitis B                        481
# Measles                              0
#  BMI                                31
# under-five deaths                    0
# Polio                               16
# Total expenditure                  191
# Diphtheria                          16
#  HIV/AIDS                            0
# GDP                                365
# Population                         540
#  thinness  1-19 years               31
#  thinness 5-9 years                 31
# Income composition of resources    141
# Schooling                          137
# dtype: int64

# %%
# check duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# garbage values (No garbage values)

for i in data.select_dtypes(include = "object").columns:
    print(data[i].value_counts())
    print("*****" * 10)
# Out:
# Country
# Hungary                  16
# Vanuatu                  16
# Armenia                  16
# Sao Tome and Principe    16
# Zimbabwe                 16
#                          ..
# San Marino                1
# Monaco                    1
# Cook Islands              1
# Tuvalu                    1
# Dominica                  1
# Name: count, Length: 192, dtype: int64
# **************************************************
# Status
# Developing    2060
# Developed      437
# Name: count, dtype: int64
# **************************************************

# %%
data.describe() #to see the stats for the float data
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2497.000000       2488.000000      2488.000000    2497.000000
# mean   2007.479375         69.143770       164.647508      28.987185
# std       4.616338          9.517112       124.080010     107.624711
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2003.000000         63.200000        74.000000       0.000000
# 50%    2007.000000         72.000000       144.000000       3.000000
# 75%    2011.000000         75.525000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2333.000000             2497.000000  2016.000000    2497.000000
# mean      4.577008              731.548870    81.008433    2431.130156
# std       4.056307             1987.075471    25.107816   11740.711517
# ...

# %%
#histogram
for i in data.select_dtypes(include = "number").columns:
    sns.histplot(data=data, x = i)
    plt.show()

# %%
for i in data.select_dtypes(include = "object").columns:
    sns.histplot(data=data, x = i)
    plt.show()

# %%
for i in data.select_dtypes(include = "number").columns:
    sns.boxplot(data=data, x = i)
    plt.show()

# %%
data.select_dtypes(include = "number").columns

for i in ['Year', 'Adult Mortality', 'infant deaths',
       'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
       'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
       ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
       ' thinness 5-9 years', 'Income composition of resources', 'Schooling']:
    sns.scatterplot(data= data, x = i, y = 'Life expectancy ')
    plt.show()

# %%
data.select_dtypes(include = "number").corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.168648        -0.067616
# Life expectancy                  0.168648          1.000000        -0.690212
# Adult Mortality                 -0.067616         -0.690212         1.000000
# infant deaths                   -0.027184         -0.207532         0.073255
# Alcohol                         -0.050612          0.402042        -0.195338
# percentage expenditure           0.039282          0.381986        -0.239462
# Hepatitis B                      0.107460          0.255634        -0.158297
# Measles                         -0.077203         -0.161178         0.025025
#  BMI                             0.101546          0.563363        -0.379365
# under-five deaths               -0.034339         -0.235205         0.087950
# Polio                            0.097424          0.467687        -0.272902
# ...

# %%
map=data.select_dtypes(include = "number").corr()
plt.figure(figsize= (15,15))
sns.heatmap(map, annot = True)
# Out:
# <Axes: >
